# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline

# %%
df=pd.read_excel("Height-Weight Data.xlsx")

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
##scatter plot
plt.scatter(df['Weight'],df['Height'])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %%
##Correlation 

df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931053
# Height  0.931053  1.000000

# %%
##Seaborn 

import seaborn as sns 
sns.pairplot(df)

# %%
# Independent and Dependent Features 

X=df[['Weight']] #independent features should be in dataframe or two dimensional array
#X
#type(df)

# %%
Y=df['Height'] #dependent variable can be in series form or 1D Array
Y
# Out:
# 0     120
# 1     135
# 2     123
# 3     145
# 4     160
# 5     163
# 6     175
# 7     182
# 8     170
# 9     176
# 10    182
# 11    175
# 12    183
# 13    170
# 14    177
# 15    140
# 16    159
# 17    150
# 18    167
# 19    129
# 20    140
# 21    160
# Name: Height, dtype: int64

# %%
#Train Test Split

from sklearn.model_selection import train_test_split 

X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
X_train.shape
# Out:
# (16, 1)

# %%
##Standardization 
##Apply z-score to all data points -- mean=0 and std deviation=1
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
#To prevent data leakage fit_transform is not used only transform is used
X_test=scaler.transform(X_test)
# Out:
# c:\Users\PARTHA SARATHI DAS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
##Apply Linear Regression

from sklearn.linear_model import LinearRegression 
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([17.12835457])

# %%
regression.intercept_
# Out:
# 161.4375

# %%
#plotting best fit line
plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train))

# %% [markdown]
# predicted_height=intercept+coef_(Weights)

# %%
#prediction for test data
y_pred=regression.predict(X_test)

# %%
#Performance Metrics

from sklearn.metrics import mean_absolute_error, mean_squared_error

mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 4724.827868077144
# 66.03790566004473
# 68.7373833374325

# %% [markdown]
# R2=1-SSR/SST
# R2=coefficient of determination SSR=sum of square of residuals SST=total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# -11.925061037293098

# %% [markdown]
# Adjusted R2=1-[(1-R2)*(n-1)/(n-k-1)]
# n=no of observations k=no of predictor variables

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# -15.15632629661637

# %%
## OLS Linear Regression 

import statsmodel.api as sm
model=sm.OLS()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[50], line 3
#       1 ## OLS Linear Regression
# ----> 3 import statsmodel.api as sm
#       4 model=sm.OLS()
#
# ModuleNotFoundError: No module named 'statsmodel'
